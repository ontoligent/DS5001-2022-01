# %% [markdown]
# # Metadata
#
# ```
# Course:   DS 5001
# Module:   00 Final Projects
# Topic:    Using SciKit Learn to Vectorize your Corpus
# ```

# %% [markdown]
# # Set Up

# %%
data_home = "../data"
local_lib = "../lib"
data_prefix = 'novels'
OHCO = ['book_id','chap_id','para_num','sent_num','token_num']

# %%
ngram_range = (1,4)
n_terms = 4000

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

# %% [markdown]
# # Import CORPUS

# %%
LIB = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-LIB.csv").set_index(OHCO[:1])

# %%
CORPUS = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-CORPUS.csv").set_index(OHCO)

# %%
CORPUS.head()
# Out:
#                                                      pos     term_str
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy

# %% [markdown]
# # Create DOC

# %%
def gather_docs(CORPUS, ohco_level, term_col='term_str'):
    OHCO = CORPUS.index.names
    CORPUS[term_col] = CORPUS[term_col].astype('str')
    DOC = CORPUS.groupby(OHCO[:ohco_level])[term_col].apply(lambda x:' '.join(x)).to_frame('doc_str')
    return DOC

# %%
DOC = gather_docs(CORPUS, 2)

# %%
DOC['n_tokens'] = DOC.doc_str.apply(lambda x: len(x.split()))

# %%
DOC
# Out:
#                                                               doc_str  \
# book_id    chap_id
# adventures 1        a scandal in bohemia i to sherlock holmes she ...
#            2        the red headed league i had called upon my fri...
#            3        a case of identity my dear fellow said sherloc...
#            4        the boscombe valley mystery we were seated at ...
#            5        the five orange pips when i glance over my not...
# ...                                                               ...
# udolpho    54       vi unnatural deeds do breed unnatural troubles...
#            55       vii but in these cases we still have judgment ...
#            56       viii then fresh tears stood on her cheek as do...
#            57       ix now my task is smoothly done i can fly or i...
# usher      1        fall of the house of usher son coeur est un lu...
#
#                     n_tokens
# book_id    chap_id
# adventures 1            8608
#            2            9197
#            3            7020
#            4            9685
#            5            7365
# ...                      ...
# udolpho    54           5605
#            55           4164
#            56           2522
#            57            977
# usher      1            7212
#
# [320 rows x 2 columns]

# %% [markdown]
# # Method 1: CountVectorizer + TfidfTransformer

# %% [markdown]
# ## Create DTM

# %%
count_engine = CountVectorizer(
    stop_words='english',
    ngram_range=ngram_range,
    max_features=n_terms)

# %%
X = count_engine.fit_transform(DOC.doc_str)

# %%
# X.toarray()

# %%
# count_engine.get_feature_names()

# %%
DTM = pd.DataFrame(X.toarray(), 
                   columns=count_engine.get_feature_names(), 
                   index=DOC.index)

# %%
DTM
# Out:
#                     abandon  abandoned  abbess  abbey  abbot  able  ablewhite  \
# book_id    chap_id
# adventures 1              0          1       0      0      0     3          0
#            2              0          0       0      0      0     5          0
#            3              0          0       0      0      0     2          0
#            4              0          0       0      0      0     3          0
#            5              0          0       0      0      0     6          0
# ...                     ...        ...     ...    ...    ...   ...        ...
# udolpho    54             0          0      22      0      0     1          0
#            55             0          1       5      0      0     1          0
#            56             0          0       0      0      0     0          0
#            57             0          0       0      0      0     0          0
# usher      1              2          0       0      0      0     0          0
#
#                     ablewhites  abode  abroad  ...  young  young ladies  \
# book_id    chap_id                             ...
# adventures 1                 0      0       0  ...      4             0
#            2                 0      0       0  ...      4             0
#            3                 0      0       1  ...      6             0
#            4                 0      0       1  ...     24             0
#            5                 0      0       0  ...     10             0
# ...                        ...    ...     ...  ...    ...           ...
# udolpho    54                0      0       0  ...      4             0
#            55                0      0       0  ...      1             0
#            56                0      0       0  ...      0             0
#            57                0      0       0  ...      0             0
# usher      1                 0      0       1  ...      0             0
#
#                     young lady  young man  young men  young woman  younger  \
# book_id    chap_id
# adventures 1                 0          0          1            0        0
#            2                 0          1          0            0        0
#            3                 3          0          0            0        1
#            4                 1          5          0            0        0
#            5                 0          4          0            0        0
# ...                        ...        ...        ...          ...      ...
# udolpho    54                0          0          1            0        0
#            55                0          0          0            0        0
#            56                0          0          0            0        0
#            57                0          0          0            0        0
# usher      1                 0          0          0            0        0
#
#                     youre  youth  youve
# book_id    chap_id
# adventures 1            0      1      0
#            2            0      2      0
#            3            0      0      1
#            4            0      1      0
#            5            0      0      0
# ...                   ...    ...    ...
# udolpho    54           0      3      0
#            55           0      1      0
#            56           0      0      0
#            57           0      1      0
# usher      1            0      1      0
#
# [320 rows x 4000 columns]

# %% [markdown]
# ## Get VOCAB

# %%
VOCAB = DTM.sum().to_frame('n')

# %%
VOCAB .sort_index()
# Out:
#                n
# abandon       44
# abandoned     68
# abbess        69
# abbey        114
# abbot         66
# ...          ...
# young woman   34
# younger       59
# youre        127
# youth        219
# youve         61
#
# [4000 rows x 1 columns]

# %%
VOCAB['n_chars'] = VOCAB.apply(lambda x: len(x.name), 1)
VOCAB['n_tokens'] = VOCAB.apply(lambda x: len(x.name.split()), 1)

# %%
VOCAB.value_counts('n_tokens')
# Out:
# n_tokens
# 1    3718
# 2     267
# 3      14
# 4       1
# dtype: int64

# %%
VOCAB[VOCAB.n_tokens == 2]
# Out:
#                      n  n_chars  n_tokens
# ah said             38        7         2
# alfred inglethorp   52       17         2
# annette said        29       12         2
# baker street        59       12         2
# baskerville hall    30       16         2
# ...                ...      ...       ...
# young ladies        36       12         2
# young lady         156       10         2
# young man          165        9         2
# young men           51        9         2
# young woman         34       11         2
#
# [267 rows x 3 columns]

# %% [markdown]
# ## Create TFIDF

# %%
# TfidfTransformer?

# %%
tfidf_engine = TfidfTransformer(norm='l2', use_idf=True)

# %%
X1 = tfidf_engine.fit_transform(DTM)

# %%
TFIDF = pd.DataFrame(X1.toarray(), columns=DTM.columns, index=DTM.index)

# %%
TFIDF
# Out:
#                      abandon  abandoned    abbess  abbey  abbot      able  \
# book_id    chap_id
# adventures 1        0.000000   0.011175  0.000000    0.0    0.0  0.018096
#            2        0.000000   0.000000  0.000000    0.0    0.0  0.025466
#            3        0.000000   0.000000  0.000000    0.0    0.0  0.012700
#            4        0.000000   0.000000  0.000000    0.0    0.0  0.013158
#            5        0.000000   0.000000  0.000000    0.0    0.0  0.049004
# ...                      ...        ...       ...    ...    ...       ...
# udolpho    54       0.000000   0.000000  0.287744    0.0    0.0  0.005013
#            55       0.000000   0.014358  0.101089    0.0    0.0  0.007750
#            56       0.000000   0.000000  0.000000    0.0    0.0  0.000000
#            57       0.000000   0.000000  0.000000    0.0    0.0  0.000000
# usher      1        0.037485   0.000000  0.000000    0.0    0.0  0.000000
#
#                     ablewhite  ablewhites  abode    abroad  ...     young  \
# book_id    chap_id                                          ...
# adventures 1              0.0         0.0    0.0  0.000000  ...  0.018946
#            2              0.0         0.0    0.0  0.000000  ...  0.015998
#            3              0.0         0.0    0.0  0.011422  ...  0.029917
#            4              0.0         0.0    0.0  0.007889  ...  0.082655
#            5              0.0         0.0    0.0  0.000000  ...  0.064134
# ...                       ...         ...    ...       ...  ...       ...
# udolpho    54             0.0         0.0    0.0  0.000000  ...  0.015747
#            55             0.0         0.0    0.0  0.000000  ...  0.006085
#            56             0.0         0.0    0.0  0.000000  ...  0.000000
#            57             0.0         0.0    0.0  0.000000  ...  0.000000
# usher      1              0.0         0.0    0.0  0.015968  ...  0.000000
#
#                     young ladies  young lady  young man  young men  \
# book_id    chap_id
# adventures 1                 0.0    0.000000   0.000000   0.012866
#            2                 0.0    0.000000   0.007394   0.000000
#            3                 0.0    0.027653   0.000000   0.000000
#            4                 0.0    0.006367   0.031834   0.000000
#            5                 0.0    0.000000   0.047425   0.000000
# ...                          ...         ...        ...        ...
# udolpho    54                0.0    0.000000   0.000000   0.010694
#            55                0.0    0.000000   0.000000   0.000000
#            56                0.0    0.000000   0.000000   0.000000
#            57                0.0    0.000000   0.000000   0.000000
# usher      1                 0.0    0.000000   0.000000   0.000000
#
#                     young woman   younger  youre     youth     youve
# book_id    chap_id
# adventures 1                0.0  0.000000    0.0  0.008457  0.000000
#            2                0.0  0.000000    0.0  0.014282  0.000000
#            3                0.0  0.011261    0.0  0.000000  0.012239
#            4                0.0  0.000000    0.0  0.006149  0.000000
#            5                0.0  0.000000    0.0  0.000000  0.000000
# ...                         ...       ...    ...       ...       ...
# udolpho    54               0.0  0.000000    0.0  0.021087  0.000000
#            55               0.0  0.000000    0.0  0.010865  0.000000
#            56               0.0  0.000000    0.0  0.000000  0.000000
#            57               0.0  0.000000    0.0  0.032976  0.000000
# usher      1                0.0  0.000000    0.0  0.012446  0.000000
#
# [320 rows x 4000 columns]

# %% [markdown]
# ## Add stats to VOCAB

# %%
VOCAB['tfidf_mean'] = TFIDF.mean()
VOCAB['df'] = DTM[DTM > 0].count()
VOCAB['dfidf'] = VOCAB.df * np.log2(len(TFIDF)/VOCAB.df)

# %%
VOCAB.sort_values('dfidf', ascending=False).head(10)
# Out:
#              n  n_chars  n_tokens  tfidf_mean   df       dfidf
# curiosity  208        9         1    0.005921  118  169.835635
# written    214        7         1    0.006185  118  169.835635
# order      227        5         1    0.005313  118  169.835635
# reply      184        5         1    0.004606  118  169.835635
# mentioned  180        9         1    0.004824  117  169.832915
# perfectly  185        9         1    0.004981  117  169.832915
# instantly  208        9         1    0.005652  117  169.832915
# company    264        7         1    0.006699  119  169.826129
# memory     208        6         1    0.006271  119  169.826129
# feelings   238        8         1    0.009555  119  169.826129

# %% [markdown]
# # Method 2: TfidfVectorizer
#
# This method combines the two.

# %%
# TfidfVectorizer?

# %% [markdown]
# ## Create TFIDF

# %%
tfidf_engine2 = TfidfVectorizer(
    stop_words='english',
    ngram_range=ngram_range,
    max_features=n_terms,
    norm='l2', 
    use_idf=True)

# %%
X2 = tfidf_engine2.fit_transform(DOC.doc_str)

# %%
TFIDF2 = pd.DataFrame(X2.toarray(), columns=tfidf_engine2.get_feature_names(), index=DTM.index)

# %%
TFIDF2
# Out:
#                      abandon  abandoned    abbess  abbey  abbot      able  \
# book_id    chap_id
# adventures 1        0.000000   0.011175  0.000000    0.0    0.0  0.018096
#            2        0.000000   0.000000  0.000000    0.0    0.0  0.025466
#            3        0.000000   0.000000  0.000000    0.0    0.0  0.012700
#            4        0.000000   0.000000  0.000000    0.0    0.0  0.013158
#            5        0.000000   0.000000  0.000000    0.0    0.0  0.049004
# ...                      ...        ...       ...    ...    ...       ...
# udolpho    54       0.000000   0.000000  0.287744    0.0    0.0  0.005013
#            55       0.000000   0.014358  0.101089    0.0    0.0  0.007750
#            56       0.000000   0.000000  0.000000    0.0    0.0  0.000000
#            57       0.000000   0.000000  0.000000    0.0    0.0  0.000000
# usher      1        0.037485   0.000000  0.000000    0.0    0.0  0.000000
#
#                     ablewhite  ablewhites  abode    abroad  ...     young  \
# book_id    chap_id                                          ...
# adventures 1              0.0         0.0    0.0  0.000000  ...  0.018946
#            2              0.0         0.0    0.0  0.000000  ...  0.015998
#            3              0.0         0.0    0.0  0.011422  ...  0.029917
#            4              0.0         0.0    0.0  0.007889  ...  0.082655
#            5              0.0         0.0    0.0  0.000000  ...  0.064134
# ...                       ...         ...    ...       ...  ...       ...
# udolpho    54             0.0         0.0    0.0  0.000000  ...  0.015747
#            55             0.0         0.0    0.0  0.000000  ...  0.006085
#            56             0.0         0.0    0.0  0.000000  ...  0.000000
#            57             0.0         0.0    0.0  0.000000  ...  0.000000
# usher      1              0.0         0.0    0.0  0.015968  ...  0.000000
#
#                     young ladies  young lady  young man  young men  \
# book_id    chap_id
# adventures 1                 0.0    0.000000   0.000000   0.012866
#            2                 0.0    0.000000   0.007394   0.000000
#            3                 0.0    0.027653   0.000000   0.000000
#            4                 0.0    0.006367   0.031834   0.000000
#            5                 0.0    0.000000   0.047425   0.000000
# ...                          ...         ...        ...        ...
# udolpho    54                0.0    0.000000   0.000000   0.010694
#            55                0.0    0.000000   0.000000   0.000000
#            56                0.0    0.000000   0.000000   0.000000
#            57                0.0    0.000000   0.000000   0.000000
# usher      1                 0.0    0.000000   0.000000   0.000000
#
#                     young woman   younger  youre     youth     youve
# book_id    chap_id
# adventures 1                0.0  0.000000    0.0  0.008457  0.000000
#            2                0.0  0.000000    0.0  0.014282  0.000000
#            3                0.0  0.011261    0.0  0.000000  0.012239
#            4                0.0  0.000000    0.0  0.006149  0.000000
#            5                0.0  0.000000    0.0  0.000000  0.000000
# ...                         ...       ...    ...       ...       ...
# udolpho    54               0.0  0.000000    0.0  0.021087  0.000000
#            55               0.0  0.000000    0.0  0.010865  0.000000
#            56               0.0  0.000000    0.0  0.000000  0.000000
#            57               0.0  0.000000    0.0  0.032976  0.000000
# usher      1                0.0  0.000000    0.0  0.012446  0.000000
#
# [320 rows x 4000 columns]

# %% [markdown]
# ## Get VOCAB

# %%
VOCAB2 = TFIDF2.mean().to_frame('tfidf_mean')

# %%
VOCAB2
# Out:
#              tfidf_mean
# abandon        0.001670
# abandoned      0.002396
# abbess         0.003529
# abbey          0.006194
# abbot          0.002089
# ...                 ...
# young woman    0.001985
# younger        0.002918
# youre          0.005334
# youth          0.005786
# youve          0.002944
#
# [4000 rows x 1 columns]

# %% [markdown]
# ## Add stats to VOCAB

# %%
VOCAB2['df'] = TFIDF2[TFIDF2 > 0].count()
VOCAB2['dfidf'] = VOCAB2.df * np.log2(len(TFIDF2)/VOCAB2.df)

# %%
VOCAB2.sort_values('dfidf', ascending=False).head(10)
# Out:
#            tfidf_mean   df       dfidf
# curiosity    0.005921  118  169.835635
# written      0.006185  118  169.835635
# order        0.005313  118  169.835635
# reply        0.004606  118  169.835635
# mentioned    0.004824  117  169.832915
# perfectly    0.004981  117  169.832915
# instantly    0.005652  117  169.832915
# company      0.006699  119  169.826129
# memory       0.006271  119  169.826129
# feelings     0.009555  119  169.826129

# %% [markdown]
# # Create BOW

# %%
BOW = DTM[DTM > 0].stack().to_frame('n').join(TFIDF[TFIDF > 0].stack().to_frame('tfidf'))

# %%
BOW
# Out:
#                                    n     tfidf
# book_id    chap_id
# adventures 1       abandoned     1.0  0.011175
#                    able          3.0  0.018096
#                    absolute      1.0  0.011175
#                    absolutely    3.0  0.027844
#                    accomplished  1.0  0.013143
# ...                              ...       ...
# usher      1       year          1.0  0.012095
#                    years         5.0  0.040830
#                    yellow        1.0  0.014559
#                    yes           1.0  0.007462
#                    youth         1.0  0.012446
#
# [229599 rows x 2 columns]

# %% [markdown]
# # Play

# %%
DOC['n_tokens_used'] = BOW.groupby(OHCO[:2]).n.sum().astype('int')
DOC['token_use_rate'] = DOC.n_tokens_used / DOC.n_tokens

# %%
DOC
# Out:
#                                                               doc_str  \
# book_id    chap_id
# adventures 1        a scandal in bohemia i to sherlock holmes she ...
#            2        the red headed league i had called upon my fri...
#            3        a case of identity my dear fellow said sherloc...
#            4        the boscombe valley mystery we were seated at ...
#            5        the five orange pips when i glance over my not...
# ...                                                               ...
# udolpho    54       vi unnatural deeds do breed unnatural troubles...
#            55       vii but in these cases we still have judgment ...
#            56       viii then fresh tears stood on her cheek as do...
#            57       ix now my task is smoothly done i can fly or i...
# usher      1        fall of the house of usher son coeur est un lu...
#
#                     n_tokens  n_tokens_used  token_use_rate
# book_id    chap_id
# adventures 1            8608           2571        0.298676
#            2            9197           2807        0.305208
#            3            7020           2161        0.307835
#            4            9685           2989        0.308622
#            5            7365           2082        0.282688
# ...                      ...            ...             ...
# udolpho    54           5605           2019        0.360214
#            55           4164           1355        0.325408
#            56           2522            944        0.374306
#            57            977            335        0.342886
# usher      1            7212           2044        0.283417
#
# [320 rows x 4 columns]

# %%
DOC.sort_values('token_use_rate').token_use_rate.plot(rot=45, figsize=(10,5));

# %%
DOC.loc['adventures'].token_use_rate.plot(style='o-');

# %%
DOC.loc['udolpho'].token_use_rate.plot(style='o-');

# %%
DOC.loc['northangerabbey'].token_use_rate.plot(style='o-');

# %%
LIB['token_use_rate_mean'] = DOC.groupby('book_id').token_use_rate.mean()
LIB['n_tokens'] = DOC.groupby('book_id').n_tokens.sum()

# %%
LIB.sort_values('token_use_rate_mean').token_use_rate_mean.plot.barh(figsize=(5,7));

# %%
LIB.sort_values('token_use_rate_mean').style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_76db51d2_a618_11ec_b6ce_acde48001122row0_col2,#T_76db51d2_a618_11ec_b6ce_acde48001122row0_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row1_col2,#T_76db51d2_a618_11ec_b6ce_acde48001122row12_col3{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row1_col3,#T_76db51d2_a618_11ec_b6ce_acde48001122row4_col3{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row2_col2{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row2_col3{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row3_col2{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row3_col3{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row4_col2{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row5_col2{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row5_col3,#T_76db51d2_a618_11ec_b6ce_acde48001122row7_col3{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row6_col2{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row6_col3{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row7_col2{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row8_col2,#T_76db51d2_a618_11ec_b6ce_acde48001122row13_col3{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row8_col3,#T_76db51d2_a618_11ec_b6ce_acde48001122row19_col3{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row9_col2{
#             background-color:  #76aad0;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row9_col3{
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row10_col2{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row10_col3{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row11_col2{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row11_col3{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row12_col2{
#             background-color:  #3b92c1;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row13_col2,#T_76db51d2_a618_11ec_b6ce_acde48001122row14_col3{
#             background-color:  #2383ba;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row14_col2{
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row15_col2{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row15_col3,#T_76db51d2_a618_11ec_b6ce_acde48001122row19_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row16_col2{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row16_col3{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row17_col2{
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row17_col3{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row18_col2{
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }#T_76db51d2_a618_11ec_b6ce_acde48001122row18_col3{
#             background-color:  #dddbec;
#             color:  #000000;
#         }</style><table id="T_76db51d2_a618_11ec_b6ce_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >genre_id</th>        <th class="col_heading level0 col1" >author_id</th>        <th class="col_heading level0 col2" >token_use_rate_mean</th>        <th class="col_heading level0 col3" >n_tokens</th>    </tr>    <tr>        <th class="index_name level0" >book_id</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76db51d2_a618_11ec_b6ce_acde48001122level0_row0" class="row_heading level0 row0" >reddeath</th>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row0_col0" class="data row0 col0" >g</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row0_col1" class="data row0 col1" >poe</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row0_col2" class="data row0 col2" >25.801150</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row0_col3" class="data row0 col3" >2434</td>
#             </tr>
#             <tr>
#                         <th id="T_76db51d2_a618_11ec_b6ce_acde48001122level0_row1" class="row_heading level0 row1" >pitandpendulum</th>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row1_col0" class="data row1 col0" >g</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row1_col1" class="data row1 col1" >poe</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row1_col2" class="data row1 col2" >26.918708</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row1_col3" class="data row1 col3" >6163</td>
#             </tr>
#             <tr>
#                         <th id="T_76db51d2_a618_11ec_b6ce_acde48001122level0_row2" class="row_heading level0 row2" >marieroget</th>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row2_col0" class="data row2 col0" >d</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row2_col1" class="data row2 col1" >poe</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row2_col2" class="data row2 col2" >27.483673</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row2_col3" class="data row2 col3" >20212</td>
#             </tr>
#             <tr>
#                         <th id="T_76db51d2_a618_11ec_b6ce_acde48001122level0_row3" class="row_heading level0 row3" >ruemorgue</th>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row3_col0" class="data row3 col0" >d</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row3_col1" class="data row3 col1" >poe</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row3_col2" class="data row3 col2" >27.978938</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row3_col3" class="data row3 col3" >13864</td>
#             </tr>
#             <tr>
#                         <th id="T_76db51d2_a618_11ec_b6ce_acde48001122level0_row4" class="row_heading level0 row4" >usher</th>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row4_col0" class="data row4 col0" >g</td>
#                         <td id="T_76db51d2_a618_11ec_b6ce_acde48001122row4_col1" class="data row4 col1" >poe</td

# %%
LIB.plot.scatter('n_tokens', 'token_use_rate_mean', logx=False);
